# %%
### SIMULATED_BNS_EOS.IPYNB -- plot EOS with strong phase transition and identify twin branch

# %%
# load packages

import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# user input

EOS_PATH = './etc/macro-DBHF_2010.csv'

# %%
data = np.genfromtxt(EOS_PATH,names=True,dtype=None,delimiter=',')

plt.plot(data['R'],data['M'])

plt.ylim(1.,2.3)
#plt.yscale('log')
plt.xlabel('R [km]')
plt.ylabel('m [Msun]')
# Out:
# Text(0, 0.5, 'm [Msun]')

# %%
plt.scatter(data['R'],data['M'])

plt.ylim(0.9,1.2)
plt.xlim(11.,14.)
plt.xlabel('R [km]')
plt.ylabel('m [Msun]')
# Out:
# Text(0, 0.5, 'm [Msun]')

# %%
plt.plot(data['M'],data['Lambda'])

plt.xlim(1.,2.3)
plt.yscale('log')
plt.xlabel('m [Msun]')
plt.ylabel('Lambda')
# Out:
# Text(0, 0.5, 'Lambda')

# %%
plt.scatter(data['M'],data['Lambda'])

plt.xlim(1.,1.2)
plt.yscale('log')
plt.ylim(1e3,1e4)
plt.xlabel('m [Msun]')
plt.ylabel('Lambda')
# Out:
# Text(0, 0.5, 'Lambda')

# %%
print(np.where(np.gradient(data['M']) < 0.))
print(data['M'][242:245])
print(data['M'][343:346])
# Out:
# (array([243, 246, 247, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258,
#        259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271,
#        272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284,
#        285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297,
#        298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310,
#        311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323,
#        324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336,
#        337, 338, 339, 340, 341, 342, 343, 789, 790, 791, 792, 793, 794,
#        795, 796, 797, 798, 799]),)
# [1.19087685 1.19087881 1.19087627]
# [1.12798818 1.12787506 1.12812   ]
